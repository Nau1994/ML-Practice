# %%
import pandas as pd
from pandas import DataFrame
order=pd.read_excel("SuperstoreSales.xls",0)
order.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Order Priority', 'Order Quantity',
#        'Sales', 'Discount', 'Ship Mode', 'Profit', 'Unit Price',
#        'Shipping Cost', 'Customer Name', 'Province', 'Region',
#        'Customer Segment', 'Product Category', 'Product Sub-Category',
#        'Product Name', 'Product Container', 'Product Base Margin',
#        'Ship Date'],
#       dtype='object')

# %%
order.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8385    False
# 8386    False
# 8387    False
# 8388    False
# 8389    False
# Length: 8390, dtype: bool

# %%
order['Customer Name'].duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 8385     True
# 8386     True
# 8387     True
# 8388     True
# 8389     True
# Name: Customer Name, Length: 8390, dtype: bool

# %%
order[order['Customer Name'].duplicated(keep='last')]['Customer Name']
# Out:
# 0           Muhammed MacIntyre
# 1                  Ruben Dartt
# 2                Liz Pelletier
# 3                Liz Pelletier
# 4                Liz Pelletier
#                  ...
# 8376                 Ed Ludwig
# 8378               Ivan Gibson
# 8381               Daniel Lacy
# 8382               Daniel Lacy
# 8385    Christina Vanderzanden
# Name: Customer Name, Length: 7595, dtype: object

# %%
order['Customer Name'].drop_duplicates().head()
# Out:
# 0    Muhammed MacIntyre
# 1           Ruben Dartt
# 2         Liz Pelletier
# 6       Julie Creighton
# 8      Sample Company A
# Name: Customer Name, dtype: object

# %%
order.drop_duplicates(subset=['Customer Name', 'Province'])
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity    Sales  \
# 0          1         3 2010-10-13            Low               6   261.54
# 1          2         6 2012-02-20  Not Specified               2     6.93
# 2          3        32 2011-07-15           High              26  2808.08
# 5          6        32 2011-07-15           High              15   140.56
# 6          7        35 2011-10-22  Not Specified              30   288.56
# ...      ...       ...        ...            ...             ...      ...
# 8347    8348     59681 2009-06-11       Critical              23   224.34
# 8357    8358     59714 2010-12-13       Critical              26  9225.65
# 8359    8360     59750 2010-07-09            Low              34   223.59
# 8366    8367     59781 2012-12-12  Not Specified              24  4408.27
# 8381    8382     59905 2012-04-14           High              19   159.24
#
#       Discount       Ship Mode      Profit  Unit Price  ...  \
# ...
