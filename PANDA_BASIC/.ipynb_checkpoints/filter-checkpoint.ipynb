# %%
import pandas as pd
order=pd.read_excel("SuperstoreSales.xls",0)
order.head(2)
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity   Sales  \
# 0       1         3 2010-10-13            Low               6  261.54
# 1       2         6 2012-02-20  Not Specified               2    6.93
#
#    Discount    Ship Mode  Profit  Unit Price  ...       Customer Name  \
# 0      0.04  Regular Air -213.25       38.94  ...  Muhammed MacIntyre
# 1      0.01  Regular Air   -4.64        2.08  ...         Ruben Dartt
#
#   Province   Region Customer Segment Product Category  \
# 0  Nunavut  Nunavut   Small Business  Office Supplies
# 1  Alberta     West        Corporate  Office Supplies
#
#             Product Sub-Category  \
# 0         Storage & Organization
# 1  Scissors, Rulers and Trimmers
#
#                                         Product Name Product Container  \
# 0   Eldon Base for stackable storage shelf, platinum         Large Box
# 1  Kleencut® Forged Office Shears by Acme United ...        Small Pack
#
#   Product Base Margin  Ship Date
# ...

# %%
order.filter(['Sales','Discount'])
# Out:
#           Sales  Discount
# 0      261.5400      0.04
# 1        6.9300      0.01
# 2     2808.0800      0.07
# 3     1761.4000      0.09
# 4      160.2335      0.04
# ...         ...       ...
# 8385  1255.4800      0.06
# 8386   411.5600      0.09
# 8387    10.5900      0.10
# 8388   235.9800      0.02
# 8389   130.9600      0.05
#
# [8390 rows x 2 columns]

# %%
order[(order['Discount']==0.04) & (order['Order Priority'].isin(['High','Low']))].head(5)
# Out:
#      Row ID  Order ID Order Date Order Priority  Order Quantity      Sales  \
# 0         1         3 2010-10-13            Low               6   261.5400
# 4         5        32 2011-07-15           High              23   160.2335
# 5         6        32 2011-07-15           High              15   140.5600
# 139     140       898 2010-06-02           High              26  7668.5500
# 144     145       929 2012-10-01           High              21   227.6600
#
#      Discount       Ship Mode      Profit  Unit Price  ...  \
# 0        0.04     Regular Air -213.250000       38.94  ...
# 4        0.04     Regular Air  -85.129000        7.99  ...
# 5        0.04     Regular Air -128.380000        8.46  ...
# 139      0.04  Delivery Truck -715.778206      296.18  ...
# 144      0.04     Regular Air -100.160000       10.97  ...
#
#           Customer Name     Province   Region Customer Segment  \
# 0    Muhammed MacIntyre      Nunavut  Nunavut   Small Business
# ...
