# %%
import pandas as pd
from pandas import DataFrame
order=pd.read_excel("SuperstoreSales.xls",0)
order.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Order Priority', 'Order Quantity',
#        'Sales', 'Discount', 'Ship Mode', 'Profit', 'Unit Price',
#        'Shipping Cost', 'Customer Name', 'Province', 'Region',
#        'Customer Segment', 'Product Category', 'Product Sub-Category',
#        'Product Name', 'Product Container', 'Product Base Margin',
#        'Ship Date'],
#       dtype='object')

# %%
ship_dummy=pd.get_dummies(order['Ship Mode']).head()

# %%
pd.concat([order,ship_dummy],axis=1)
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity      Sales  \
# 0          1         3 2010-10-13            Low               6   261.5400
# 1          2         6 2012-02-20  Not Specified               2     6.9300
# 2          3        32 2011-07-15           High              26  2808.0800
# 3          4        32 2011-07-15           High              24  1761.4000
# 4          5        32 2011-07-15           High              23   160.2335
# ...      ...       ...        ...            ...             ...        ...
# 8385    8386     59909 2012-08-05            Low              11  1255.4800
# 8386    8387     59909 2012-08-05            Low              46   411.5600
# 8387    8388     59911 2011-12-18  Not Specified               1    10.5900
# 8388    8389     59937 2009-12-28           High               7   235.9800
# 8389    8390     59939 2010-09-01         Medium              42   130.9600
#
# ...

# %%
order=pd.get_dummies(order,columns=['Ship Mode','Order Priority'],drop_first=True).head()

# %%
order
# Out:
#    Row ID  Order ID Order Date  Order Quantity      Sales  Discount    Profit  \
# 0       1         3 2010-10-13               6   261.5400      0.04  -213.250
# 1       2         6 2012-02-20               2     6.9300      0.01    -4.640
# 2       3        32 2011-07-15              26  2808.0800      0.07  1054.820
# 3       4        32 2011-07-15              24  1761.4000      0.09 -1748.560
# 4       5        32 2011-07-15              23   160.2335      0.04   -85.129
#
#    Unit Price  Shipping Cost       Customer Name  ...  \
# 0       38.94          35.00  Muhammed MacIntyre  ...
# 1        2.08           2.56         Ruben Dartt  ...
# 2      107.53           5.81       Liz Pelletier  ...
# 3       70.89          89.30       Liz Pelletier  ...
# 4        7.99           5.03       Liz Pelletier  ...
#
#                                         Product Name Product Container  \
# 0   Eldon Base for stackable storage shelf, platinum         Large Box
# ...
